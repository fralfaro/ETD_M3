# %% [markdown]
# <a href="https://colab.research.google.com/github/fralfaro/ETD_M3/blob/main/semana_03/d_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
#
# # Actividad: Uso critico de IA para apoyo en programacion
#
# En este notebook vas a usar un asistente de IA (ChatGPT, Gemini, Claude u otro) para apoyar tareas simples de analisis de datos en Python.
#
# Documenta siempre:
# - Prompt utilizado
# - Respuesta entregada por la IA
# - Tu evaluacion critica
# - Ajustes realizados al prompt

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Utilizar asistentes de IA para apoyar tareas de programacion.
# - Formular prompts claros para resolver problemas tecnicos.
# - Evaluar criticamente la calidad de respuestas generadas por IA.
# - Identificar limitaciones y errores en respuestas de IA.
# - Reflexionar sobre uso responsable de IA en contextos profesionales.

# %% [markdown]
# ---
#
# ## Parte 1: Comprension del codigo

# %%
import pandas as pd

data = {
    "horas_estudio": [2, 5, 1, 4, 6, 3],
    "asistencia": [60, 90, 50, 80, 95, 70],
    "resultado": [0, 1, 0, 1, 1, 0]
}

df = pd.DataFrame(data)
df.describe()

# %% [markdown]
# ### Responde (Markdown)
#
# 1. Que informacion entrega `df.describe()`?
# 2. Que tipo de variables contiene el dataset?
#
# **Tu respuesta:**
#
# -
# -

# %% [markdown]
# ---
#
# ## Parte 2: Uso de IA para mejorar el analisis

# %%
import matplotlib.pyplot as plt

plt.scatter(df["horas_estudio"], df["resultado"])

# TODO: agregar etiquetas al grafico
# TODO: agregar titulo
# TODO: mostrar grafico

# %% [markdown]
# ### Prompt utilizado
#
# Escribe aqui el prompt que usaste para pedir ayuda a la IA.
#
# **Respuesta:**
#
# ```text
#
# ```

# %% [markdown]
# ### Respuesta de la IA
#
# Copia aqui el codigo sugerido por el asistente.
#
# **Respuesta:**
#
# ```python
#
# ```

# %%
# Pega y ejecuta aqui el codigo ajustado/final sugerido por la IA

# %% [markdown]
# ### Evaluacion
#
# Responde:
#
# 1. El codigo sugerido funciono correctamente?
# 2. Tuviste que modificar algo?
# 3. La explicacion del asistente fue clara?
#
# **Tu respuesta:**
#
# -
# -
# -

# %% [markdown]
# ---
#
# ## Parte 3: Refinamiento del prompt

# %% [markdown]
# Mejora tu prompt inicial agregando contexto:
# - que hace el codigo
# - que libreria estas usando
# - que resultado esperas

# %% [markdown]
# ### Prompt mejorado
#
# ```text
#
# ```

# %% [markdown]
# ### Nueva respuesta del asistente
#
# ```python
#
# ```

# %% [markdown]
# ### Comparacion
#
# Responde:
#
# 1. La nueva respuesta fue mejor que la anterior?
# 2. Que diferencias observas?
# 3. Que aprendiste sobre como formular prompts?
#
# **Tu respuesta:**
#
# -
# -
# -

# %% [markdown]
# ---
#
# ## Parte 4: Uso de IA para interpretar resultados

# %% [markdown]
# Ejecuta el grafico final y luego consulta a la IA algo como:
#
# > Que interpretacion se podria hacer de este grafico?

# %% [markdown]
# ### Documenta
#
# - Prompt utilizado:
#
# ```text
#
# ```
#
# - Respuesta del sistema:
#
# ```text
#
# ```

# %% [markdown]
# ### Analisis
#
# Responde:
#
# 1. La interpretacion del asistente te parece correcta?
# 2. Hay afirmaciones exageradas o poco justificadas?
#
# **Tu respuesta:**
#
# -
# -

# %% [markdown]
# ---
#
# ## Parte 5: Reflexion critica sobre el uso de IA

# %% [markdown]
# Responde:
#
# 1. En que aspectos el asistente de IA fue util durante esta actividad?
# 2. En que momentos fue necesario revisar o corregir sus respuestas?
# 3. Que riesgos existirian si un programador utilizara estas respuestas sin revisarlas?
# 4. En que tipo de tareas tecnicas consideras mas util el apoyo de IA?
#
# **Tu respuesta:**
#
# 1.
# 2.
# 3.
# 4.
